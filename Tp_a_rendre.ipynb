# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

# %%
url_ligue_1 = "https://fr.wikipedia.org/wiki/Championnat_de_France_de_football_2019-2020"


page = requests.get(url_ligue_1)
soup = BeautifulSoup(page.content, "html.parser")

# %% [markdown]
#  ### Exercice 1 : Récupérer les participants de la Ligue 1
# Pour cela, nous allons procéder en 6 étapes:
#
# 1-Trouver le tableau
#
# 2-Récupérer chaque ligne du table
#
# 3-Nettoyer les sorties en ne gardant que le texte sur une ligne
#
# 4-Généraliser sur toutes les lignes
#
# 5-Récupérer les entêtes du tableau
#
# 6-Finalisation du tableau

# %%
league_one_club_table = soup.findAll("table")[5]

def parse_string(string: str):
    string = string.lstrip().replace('\n', ' ').replace('\xa0', ' ')
    return re.sub(r'\[.*?\]', '', string)

table_headers = []
for th in league_one_club_table.findAll('th'): table_headers.append(parse_string(th.get_text(separator=' ')))

table_content= []
for tr in league_one_club_table.findAll('tr'):
    table_line = []
    for td in tr.findAll('td'): table_line.append(parse_string(td.get_text(separator=' ')))
    if(len(table_line) != 0 ): table_content.append(table_line)

df = pd.DataFrame(table_content, columns=table_headers)

df
# Out:
#                        Club  Dernière montée  Budget  en M €    \
# 0      Paris Saint-Germain              1974              637
# 1               LOSC Lille              2000              120
# 2       Olympique lyonnais              1989              310
# 3         AS Saint-Étienne              2004              100
# 4   Olympique de Marseille              1996              110
# 5          Montpellier HSC              2009               40
# 6                 OGC Nice              2002               50
# 7           Stade de Reims              2018               45
# 8          Nîmes Olympique              2018               27
# 9         Stade rennais FC              1994               65
# 10    RC Strasbourg Alsace              2017               43
# 11               FC Nantes              2013               70
# 12            SCO d’Angers              2015               32
# 13   Girondins de Bordeaux              1992               70
# 14               Amiens SC              2017               30
# 15             Toulouse FC              2003               35
# 16               AS Monaco              2013              220
# 17               Dijon FCO              2016               38
# 18                 FC Metz              2019               40
# 19       Stade brestois 29              2019               30
#
#    Classement 2018-2019              Entraîneur  Depuis   \
# 0                  1 er          Thomas Tuchel     2018
# 1                   2 e     Christophe Galtier     2017
# 2                   3 e            Rudi Garcia     2019
# 3                   4 e            Claude Puel     2019
# 4                   5 e      André Villas-Boas     2019
# 5                   6 e    Michel Der Zakarian     2017
# 6                   7 e         Patrick Vieira     2018
# 7                   8 e            David Guion     2017
# 8                   9 e       Bernard Blaquart     2015
# 9                  10 e         Julien Stéphan     2018
# 10                 11 e         Thierry Laurey     2016
# 11                 12 e     Christian Gourcuff     2019
# 12                 13 e        Stéphane Moulin     2011
# 13                 14 e            Paulo Sousa     2019
# 14                 15 e            Luka Elsner     2019
# 15                 16 e            Denis Zanko     2020
# 16                 17 e          Robert Moreno     2019
# 17                 18 e        Stéphane Jobard     2019
# 18     1 er  ( Ligue 2 )        Vincent Hognon     2019
# 19      2 e  ( Ligue 2 )    Olivier Dall'Oglio     2019
#
#                                        Stade  Capacité en L1     \
# 0                          Parc des Princes             47 929
# 1                       Stade Pierre-Mauroy             49 712
# 2                          Groupama Stadium             57 206
# 3                   Stade Geoffroy-Guichard             41 965
# 4                          Orange Vélodrome             66 226
# 5                        Stade de la Mosson             22 000
# 6                           Allianz Riviera             35 596
# 7                     Stade Auguste-Delaune             20 546
# 8                       Stade des Costières             15 788
# 9                              Roazhon Park             29 194
# 10                       Stade de la Meinau             26 109
# 11  Stade de la Beaujoire - Louis Fonteneau             35 322
# 12                       Stade Raymond-Kopa             14 582
# 13                        Matmut Atlantique             42 115
# 14         Stade Crédit Agricole la Licorne             12 999
# 15                      Stadium de Toulouse             33 033
# 16                           Stade Louis-II             16 500
# 17            Parc des Sports Gaston-Gérard             15 459
# 18                   Stade Saint-Symphorien             25 865
# 19                     Stade Francis-Le Blé             14 920
#
#    Nombre de saisons en L1
# 0                       46
# 1                       59
# 2                       60
# 3                       66
# 4                       69
# 5                       27
# 6                       60
# 7                       35
# 8                       35
# 9                       62
# 10                      58
# 11                      51
# 12                      27
# 13                      66
# 14                       2
# 15                      32
# 16                      60
# 17                       4
# 18                      61
# 19                      13
