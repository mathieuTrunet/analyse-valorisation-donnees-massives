# %% [markdown]
# # Tp pour l'utilisation de panda
#
# # Importation de packages
#
# import numpy as np
# import pandas as pd
#
# Utilisez le lien suivant pour importer la base de données
# https://koumoul.com/s/data-fair/api/v1/datasets/igt-pouvoir-de-rechauffement-global/convert
#
# Utilisez read_csv pour lire les données
#
# 1-Affichez le tableau des données
#
# 2-Affichez le nom de chaque "colums"
#
# 3-Affichez les 10 première lignes, les 10 dernière et les lignes entre 100, 120.
#
# 4-Afficher le type de chaque "colums".
#
# 5- Remplacer les espaces par _ dans les noms des colonnes.
#
# 6-affichez les informations de cette base de données (mean, min , max).
#
# 7- Enlevez  les colonnes "Autres transports" et "Autres transports international"
#
# 8-Créez un nouveau tableau qui contient deux colums "commune" et "déchets"
#
# 9-Triez le tableau (  décroissante) et enlevez les lignes avec information manquante " NaN".
#
# 9B-Affichez la commune qui a plus de déchets et la commune qui a le moins
#
# 10-Remplacer un nom de commune (par exemple 'BEZONVAUX' par 'Commune non identifié')
#
# 11-Afficher les commune qui ont les Déchet < 10^5.
#
# 12- Définir la colonne 'Commune' comme l'index du Dataframe
#
# 13- Affichez la ligne de la commune RANZEVELLE avec tout les colonnes (utilisez loc)

# %%
from numpy import array
from pandas import read_csv

# %%
data = read_csv('https://koumoul.com/s/data-fair/api/v1/datasets/igt-pouvoir-de-rechauffement-global/convert')

data
# Out:
#       INSEE commune                  Commune  Agriculture  Autres transports  \
# 0             01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
# 1             01002    L'ABERGEMENT-DE-VAREY   475.330205                NaN
# 2             01004        AMBERIEU-EN-BUGEY   499.043526         212.577908
# 3             01005      AMBERIEUX-EN-DOMBES  1859.160954                NaN
# 4             01006                  AMBLEON   448.966808                NaN
# ...             ...                      ...          ...                ...
# 35793         95676       VILLERS-EN-ARTHIES  1628.065094                NaN
# 35794         95678            VILLIERS-ADAM   698.630772                NaN
# 35795         95680          VILLIERS-LE-BEL   107.564967                NaN
# 35796         95682          VILLIERS-LE-SEC  1090.890170                NaN
# 35797         95690      WY-DIT-JOLI-VILLAGE  1495.103542                NaN
#
# ...

# %%
data.columns

## OU

columns = []
for col in data:
    columns.append(col)

columns
# Out:
# ['INSEE commune',
#  'Commune',
#  'Agriculture',
#  'Autres transports',
#  'Autres transports international',
#  'CO2 biomasse hors-total',
#  'Déchets',
#  'Energie',
#  'Industrie hors-énergie',
#  'Résidentiel',
#  'Routier',
#  'Tertiaire']

# %%
data.head(10)
# Out:
#   INSEE commune                  Commune  Agriculture  Autres transports  \
# 0         01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
# 1         01002    L'ABERGEMENT-DE-VAREY   475.330205                NaN
# 2         01004        AMBERIEU-EN-BUGEY   499.043526         212.577908
# 3         01005      AMBERIEUX-EN-DOMBES  1859.160954                NaN
# 4         01006                  AMBLEON   448.966808                NaN
# 5         01007                 AMBRONAY  4390.996698         132.968268
# 6         01008                 AMBUTRIX   489.648726          60.233517
# 7         01009         ANDERT-ET-CONDON   676.468367                NaN
# 8         01010                ANGLEFORT  1070.411510         143.815664
# 9         01011                 APREMONT  2010.790441                NaN
#
#    Autres transports international  CO2 biomasse hors-total      Déchets  \
# 0                              NaN               432.751835   101.430476
# ...

# %%
data.tail(10)
# Out:
#       INSEE commune              Commune  Agriculture  Autres transports  \
# 35788         95652              VIARMES   252.094735          55.168176
# 35789         95656    VIENNE-EN-ARTHIES   324.827105                NaN
# 35790         95658                VIGNY  1289.190261                NaN
# 35791         95660  VILLAINES-SOUS-BOIS   447.132894          18.996282
# 35792         95675             VILLERON  1335.123315           4.975886
# 35793         95676   VILLERS-EN-ARTHIES  1628.065094                NaN
# 35794         95678        VILLIERS-ADAM   698.630772                NaN
# 35795         95680      VILLIERS-LE-BEL   107.564967                NaN
# 35796         95682      VILLIERS-LE-SEC  1090.890170                NaN
# 35797         95690  WY-DIT-JOLI-VILLAGE  1495.103542                NaN
#
#        Autres transports international  CO2 biomasse hors-total      Déchets  \
# 35788                              NaN              1278.247866    43.526914
# ...

# %%
data[100:120]
# Out:
#     INSEE commune                Commune  Agriculture  Autres transports  \
# 100         01108                COLIGNY  1511.072353          88.881769
# 101         01109              COLLONGES  3072.915655         200.240698
# 102         01110               COLOMIEU   623.859172                NaN
# 103         01111                 CONAND   160.139326                NaN
# 104         01112              CONDAMINE   441.833276                NaN
# 105         01113            CONDEISSIAT  6523.517707                NaN
# 106         01114                CONFORT   920.380062                NaN
# 107         01115             CONFRANCON  4222.906321                NaN
# 108         01116              CONTREVOZ  1113.763283                NaN
# 109         01117                CONZIEU   693.312403                NaN
# 110         01118               CORBONOD  2244.401789          94.561375
# 111         01121                CORLIER   763.841870                NaN
# ...

# %%
data.dtypes
# Out:
# INSEE commune                       object
# Commune                             object
# Agriculture                        float64
# Autres transports                  float64
# Autres transports international    float64
# CO2 biomasse hors-total            float64
# Déchets                            float64
# Energie                            float64
# Industrie hors-énergie             float64
# Résidentiel                        float64
# Routier                            float64
# Tertiaire                          float64
# dtype: object

# %%
data.rename(columns= lambda x: x.replace(' ','_'))
# Out:
#       INSEE_commune                  Commune  Agriculture  Autres_transports  \
# 0             01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
# 1             01002    L'ABERGEMENT-DE-VAREY   475.330205                NaN
# 2             01004        AMBERIEU-EN-BUGEY   499.043526         212.577908
# 3             01005      AMBERIEUX-EN-DOMBES  1859.160954                NaN
# 4             01006                  AMBLEON   448.966808                NaN
# ...             ...                      ...          ...                ...
# 35793         95676       VILLERS-EN-ARTHIES  1628.065094                NaN
# 35794         95678            VILLIERS-ADAM   698.630772                NaN
# 35795         95680          VILLIERS-LE-BEL   107.564967                NaN
# 35796         95682          VILLIERS-LE-SEC  1090.890170                NaN
# 35797         95690      WY-DIT-JOLI-VILLAGE  1495.103542                NaN
#
# ...

# %%
data.describe()
# Out:
#         Agriculture  Autres transports  Autres transports international  \
# count  35736.000000        9979.000000                     2.891000e+03
# mean    2459.975760         654.919940                     7.692345e+03
# std     2926.957701        9232.816833                     1.137643e+05
# min        0.003432           0.000204                     3.972950e-04
# 25%      797.682631          52.560412                     1.005097e+01
# 50%     1559.381285         106.795928                     1.992434e+01
# 75%     3007.883903         237.341501                     3.298311e+01
# max    98949.317760      513140.971691                     3.303394e+06
#
#        CO2 biomasse hors-total        Déchets       Energie  \
# count             35798.000000   35792.000000  3.449000e+04
# mean               1774.381550     410.806329  6.625698e+02
# std                7871.341922    4122.472608  2.645571e+04
# min                   3.758088       0.132243  2.354558e+00
# ...

# %%
data.drop(columns=['Autres transports', 'Autres transports international'])
# Out:
#       INSEE commune                  Commune  Agriculture  \
# 0             01001  L'ABERGEMENT-CLEMENCIAT  3711.425991
# 1             01002    L'ABERGEMENT-DE-VAREY   475.330205
# 2             01004        AMBERIEU-EN-BUGEY   499.043526
# 3             01005      AMBERIEUX-EN-DOMBES  1859.160954
# 4             01006                  AMBLEON   448.966808
# ...             ...                      ...          ...
# 35793         95676       VILLERS-EN-ARTHIES  1628.065094
# 35794         95678            VILLIERS-ADAM   698.630772
# 35795         95680          VILLIERS-LE-BEL   107.564967
# 35796         95682          VILLIERS-LE-SEC  1090.890170
# 35797         95690      WY-DIT-JOLI-VILLAGE  1495.103542
#
#        CO2 biomasse hors-total      Déchets     Energie  \
# 0                   432.751835   101.430476    2.354558
# 1                   140.741660   140.675439    2.354558
# 2                 10313.446515  5314.314445  998.332482
# ...

# %%
reduced_df = data[['Commune', 'Déchets']].copy()

reduced_df
# Out:
#                        Commune      Déchets
# 0      L'ABERGEMENT-CLEMENCIAT   101.430476
# 1        L'ABERGEMENT-DE-VAREY   140.675439
# 2            AMBERIEU-EN-BUGEY  5314.314445
# 3          AMBERIEUX-EN-DOMBES   216.217508
# 4                      AMBLEON    48.401549
# ...                        ...          ...
# 35793       VILLERS-EN-ARTHIES    65.063617
# 35794            VILLIERS-ADAM   111.480954
# 35795          VILLIERS-LE-BEL   225.622903
# 35796          VILLIERS-LE-SEC   108.969749
# 35797      WY-DIT-JOLI-VILLAGE    97.728612
#
# [35798 rows x 2 columns]

# %%
data.sort_values(by='Déchets',ascending=False)

data = data.dropna()

data
# Out:
#       INSEE commune                Commune  Agriculture  Autres transports  \
# 14            01016                ARBIGNY  1659.900746         382.957621
# 19            01023     ASNIERES-SUR-SAONE  1595.032852          93.343398
# 26            01030             BEAUREGARD   456.156081          45.030749
# 51            01057                    BOZ  1051.119972          72.624599
# 113           01123  CORMORANCHE-SUR-SAONE   705.349982         253.233559
# ...             ...                    ...          ...                ...
# 35757         95527       ROISSY-EN-FRANCE  1150.313505       44883.982753
# 35767         95572    SAINT-OUEN-L'AUMONE   205.745038         853.382073
# 35783         95628             VALMONDOIS   646.421867           9.055189
# 35785         95637                VAUREAL   203.969473          93.811651
# 35787         95651               VETHEUIL   125.928390         175.096168
#
# ...

# %%
groupby = data.groupby('Commune')['Déchets'].sum()

more = groupby.max()
less = groupby.min()

print(groupby.idxmax(), more)
print(groupby.idxmin(), less)
# Out:
# FOS-SUR-MER 275500.37443878
# RANZEVELLE 3.17383498527132

# %%
data.loc[data['Commune'] == 'BEZONVAUX', 'Commune'] = 'non identifié'

# %%
data[data['Déchets'] < 10**5]['Commune']
# Out:
# 14                     ARBIGNY
# 19          ASNIERES-SUR-SAONE
# 26                  BEAUREGARD
# 51                         BOZ
# 113      CORMORANCHE-SUR-SAONE
#                  ...
# 35757         ROISSY-EN-FRANCE
# 35767      SAINT-OUEN-L'AUMONE
# 35783               VALMONDOIS
# 35785                  VAUREAL
# 35787                 VETHEUIL
# Name: Commune, Length: 2818, dtype: object

# %%
data = data.set_index('Commune')

# %%
data.loc['RANZEVELLE']
# Out:
# INSEE commune                            70437
# Agriculture                        1312.166316
# Autres transports                   163.779604
# Autres transports international       9.449343
# CO2 biomasse hors-total              70.896891
# Déchets                               3.173835
# Energie                               2.354558
# Industrie hors-énergie                6.911213
# Résidentiel                           13.83034
# Routier                             134.551058
# Tertiaire                            11.484835
# Name: RANZEVELLE, dtype: object

# %% [markdown]
# # Exercice 2
#
# A partir de l'ensemble de données donné automobile_data.csv ,
#
# Afficher  les cinq premières et dernières lignes.
#
# Nettoyer l'ensemble de données et mettre à jour le fichier CSV
#
# Conseil  : remplacez toutes les valeurs de colonne qui contiennent ?, n.a, ou NaN.
#
# Trouver le nom de l'entreprise automobile la plus chère
#
# Affichez  les détails de toutes les voitures Toyota
#
# Compter le nombre total de voitures par société
#
# Trouver la voiture la plus chère de chaque société
#
# Déterminer le kilométrage moyen de chaque constructeur automobile
#
# Trier toutes les voitures par colonne de prix

# %%
from pandas import read_csv

data = read_csv('data_automobile.csv')

data
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
data.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
data.tail(5)
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# ...

# %%
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 0  alfa-romero       gas        std
# 1            3                 0  alfa-romero       gas        std
# 2            1                 0  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
data.replace(['?', 'n.a', 'NaN'], [None, None, None], inplace=True)

data
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 0  alfa-romero       gas        std
# 1            3                 0  alfa-romero       gas        std
# 2            1                 0  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
data[data['make'] == 'toyota']
# Out:
#      symboling normalized-losses    make fuel-type aspiration num-of-doors  \
# 150          1                87  toyota       gas        std          two
# 151          1                87  toyota       gas        std          two
# 152          1                74  toyota       gas        std         four
# 153          0                77  toyota       gas        std         four
# 154          0                81  toyota       gas        std         four
# 155          0                91  toyota       gas        std         four
# 156          0                91  toyota       gas        std         four
# 157          0                91  toyota       gas        std         four
# 158          0                91  toyota    diesel        std         four
# 159          0                91  toyota    diesel        std         four
# 160          0                91  toyota       gas        std         four
# ...

# %%
data['make'].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %%
data['price'] = data['price'].astype(float)

data.loc[data.groupby('make')['price'].idxmax()]
# Out:
#      symboling normalized-losses           make fuel-type aspiration  \
# 1            3                 0    alfa-romero       gas        std
# 8            1               158           audi       gas      turbo
# 16           0                 0            bmw       gas        std
# 20           0                81      chevrolet       gas        std
# 29           3               145          dodge       gas      turbo
# 41           0                85          honda       gas        std
# 46           2                 0          isuzu       gas        std
# 49           0                 0         jaguar       gas        std
# 66           0                 0          mazda    diesel        std
# 74           1                 0  mercedes-benz       gas        std
# 75           1                 0        mercury       gas      turbo
# 83           3                 0     mitsubishi       gas      turbo
# 105          3               194         nissan       gas      turbo
# ...

# %%
data.groupby('make')['city-mpg'].mean()
# Out:
# make
# alfa-romero      20.333333
# audi             18.857143
# bmw              19.375000
# chevrolet        41.000000
# dodge            28.000000
# honda            30.384615
# isuzu            31.000000
# jaguar           14.333333
# mazda            25.705882
# mercedes-benz    18.500000
# mercury          19.000000
# mitsubishi       24.923077
# nissan           27.000000
# peugot           22.454545
# plymouth         28.142857
# porsche          17.400000
# renault          23.000000
# saab             20.333333
# subaru           26.333333
# toyota           27.500000
# volkswagen       28.583333
# volvo            21.181818
# Name: city-mpg, dtype: float64

# %%
data.sort_values(by='price', ascending=False)
# Out:
#      symboling normalized-losses           make fuel-type aspiration  \
# 74           1                 0  mercedes-benz       gas        std
# 16           0                 0            bmw       gas        std
# 73           0                 0  mercedes-benz       gas        std
# 128          3                 0        porsche       gas        std
# 17           0                 0            bmw       gas        std
# ..         ...               ...            ...       ...        ...
# 138          2                83         subaru       gas        std
# 44           1                 0          isuzu       gas        std
# 45           0                 0          isuzu       gas        std
# 129          1                 0        porsche       gas        std
# 9            0                 0           audi       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...
